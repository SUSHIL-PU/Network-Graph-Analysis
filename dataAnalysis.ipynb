# %%
import networkx as nx
import matplotlib.pyplot as plt

# %%
G = nx.read_gml("DATASET/lesmiserables.gml")
G

# %%
nx.spring_layout(G)
nx.draw_networkx(G)

# %%
print(nx.info(G))
# Out:
# Name:
# Type: Graph
# Number of nodes: 77
# Number of edges: 254
# Average degree:   6.5974

# %%
nx.is_directed(G)
# Out:
# False

# %%
nx.is_weighted(G)
# Out:
# False
